# %% [markdown]
# # Hobohm 2
#
# ### Fill in the blanked out parts of the code (XX's)

# %% [markdown]
# ## Python Imports

# %%
import numpy as np
from time import time

# %% [markdown]
# ## Data Imports

# %% [markdown]
# ## DEFINE THE PATH TO YOUR COURSE DIRECTORY

# %%
data_dir = "/home/mathias/bioinfo_algos/data/"

# %%
# File with formated similarity scores
alignment_file_part = data_dir + "Hobohm/alignment_aln.fmt"

alignment_output = np.loadtxt(alignment_file_part, dtype=str)

# %% [markdown]
# ## Get list of unique ID's in alignment file

# %%
def get_IDlist(alignment_output):

    IDlist = []
    first = 1
    
    for row in alignment_output:
        
        # The first entry is only included as query
        if first:
            id = row[0]
            first = 0
            if id not in IDlist:
                IDlist.append(id)
            
        id = row[1]
    
        if id not in IDlist:
            IDlist.append(id)
        
    return( IDlist )

# %% [markdown]
# ## Main code

# %%
t0 = time()

ID_list = get_IDlist(alignment_output)

nid_list = len(ID_list)

print ("NID:", nid_list)
neighbor_matrix = np.zeros(shape=(nid_list, nid_list))

for i in range(nid_list):
    neighbor_matrix[i][i] = 1

for row in alignment_output:
        
    query_id = row[0]
    database_id = row[1]
    match = row[2]
    
    ix = ID_list.index( query_id )
    iy = ID_list.index( database_id )
    
    neighbor_matrix[ix][iy] = match
    neighbor_matrix[iy][ix] = match
    
used = np.zeros(nid_list)

left = 1

while left > 0:
    max_nn = -99;
    n_max = -9
    
    for i in range(nid_list):

        if used[i] == 0:
            
            nn = 0
            
            for j in range(nid_list):
                if used[j] == 0 and neighbor_matrix[i][j] == 1:
                    nn += 1
            
            if nn > max_nn:
                max_nn = nn
                n_max = i
    
    print ("# Remove", max_nn, n_max, ID_list[n_max])
    if max_nn == 1:
        left = 0
    else:
        used[n_max] = 1
        
t1 = time()
print ("Elapsed time (m):", (t1-t0)/60)
        
ncl = 0;
for i in range(nid_list):
    if used[i] == 0: 
        print  ("Unique", ID_list[i], ncl)
        ncl += 1
        
print ("Number of unique sequences:", ncl)
# Out:
# NID: 1052
# # Remove 846 65 1OFE.A
# # Remove 831 20 1T3T.A
# # Remove 815 57 1C7S.A
# # Remove 808 973 2HZ7.A
# # Remove 798 50 2GAG.A
# # Remove 797 136 1ITW.A
# # Remove 795 2 1QWN.A
# # Remove 794 699 1L5G.A
# # Remove 791 446 1W36.C
# # Remove 789 193 2CFU.A
# # Remove 787 155 1N0U.A
# # Remove 784 171 2J7N.A
# # Remove 782 427 6ACN.A
# # Remove 778 10 1JZ7.A
# # Remove 777 39 2HPO.A
# # Remove 773 168 1WB9.A
# # Remove 771 478 1QHB.A
# # Remove 769 3 1HLR.A
# # Remove 767 165 1O94.A
# # Remove 763 773 1OD2.A
# # Remove 761 326 2GQ3.A
# # Remove 760 392 1PO0.A
# # Remove 756 33 1H16.A
# # Remove 755 160 1UVJ.A
# # Remove 752 212 1QHT.A
# # Remove 750 707 2FGH.A
# # Remove 747 74 1FGQ.A
# # Remove 746 205 1IVU.A
# # Remove 744 124 2NQ5.A
# # Remove 743 614 2EC5.A
# # Remove 740 9 2E7Z.A
# # Remove 738 119 1NNM.A
# # Remove 735 415 1U6G.C
# # Remove 733 92 1EDQ.A
# # Remove 732 170 2HR0.B
# # Remove 730 275 1P30.A
# # Remove 728 1 2EAB.A
# # Remove 727 58 1Y2M.B
# # Remove 726 183 1QHA.B
# # Remove 724 18 1M1N.B
# # Remove 722 153 1WPG.A
# # Remove 721 163 1X6V.A
# # Remove 720 332 1R9J.B
# # Remove 719 969 1E3H.A
# # Remove 717 28 1QKS.A
# # Remove 716 264 2OAJ.A
# # Remove 715 301 2HU5.B
# # Remove 714 484 2FKN.B
# # Remove 712 44 1HDH.A
# # Remove 711 86 1FWX.A
# # Remove 710 451 1VA6.A
# # Remove 707 141 1RLL.A
# # Remove 706 329 1JMX.A
# # Remove 703 117 1X38.A
# # Remove 702 213 1W07.A
# # Remove 699 181 1P5D.X
# # Remove 696 110 1MW9.X
# # Remove 695 169 1XJJ.A
# # Remove 694 425 1DPG.A
# # Remove 692 551 1H38.A
# # Remove 691 688 1Q15.A
# # Remove 689 776 1H77.A
# # Remove 687 13 1LQT.A
# # Remove 686 101 2PY5.A
# # Remove 685 172 1HP1.A
# # Remove 684 196 1LJ8.A
# # Remove 680 36 1G5A.A
# # Remove 679 99 2EZ9.A
# # Remove 678 104 2V0C.A
# # Remove 677 951 1TXK.A
# # Remove 675 75 1W9I.A
# # Remove 674 81 1E7U.A
# # Remove 672 143 1Q7Z.A
# # Remove 671 396 1ZCZ.B
# # Remove 669 34 2GJ4.A
# # Remove 668 63 1JNR.A
# # Remove 667 83 2AKZ.A
# # Remove 665 7 1WUI.L
# # Remove 663 130 1QMG.A
# # Remove 661 54 1LLF.A
# # Remove 660 388 1XEZ.A
# # Remove 658 35 1N7O.A
# # Remove 657 167 1GPE.A
# # Remove 656 224 1X1N.A
# # Remove 655 372 1LLA._
# # Remove 654 448 1BJT._
# # Remove 652 151 2G50.D
# # Remove 651 575 1W5D.A
# # Remove 649 228 1W96.C
# # Remove 648 349 2PTR.A
# # Remove 646 8 2BHU.A
# # Remove 645 530 1CJY.A
# # Remove 641 215 1YIF.A
# # Remove 640 378 2G95.B
# # Remove 638 715 2O8R.A
# # Remove 636 989 1JMU.B
# # Remove 634 194 1Y79.1
# # Remove 633 266 1PEV.A
# # Remove 632 267 1PMI._
# # Remove 631 785 1PGN._
# # Remove 629 900 2B5E.A
# # Remove 629 909 1HWX.A
# # Remove 626 4 1MXT.A
# # Remove 625 97 1F0L.A
# # Remove 624 289 2D7D.A
# # Remove 623 417 2DW5.A
# # Remove 621 693 1PJR._
# # Remove 619 15 1MRO.A
# # Remove 618 94 1JU3.A
# # Remove 617 631 2GV8.A
# # Remove 615 281 1GES.B
# # Remove 614 546 1AX4.A
# # Remove 612 331 1ZFJ.A
# # Remove 609 166 1MV8.A
# # Remove 607 293 2QMA.A
# # Remove 606 300 2HC9.A
# # Remove 605 702 2AX3.A
# # Remove 603 217 1W6K.A
# # Remove 602 782 1QRC.A
# # Remove 600 77 1G87.B
# # Remove 599 405 1RT8.A
# # Remove 598 613 2I09.A
# # Remove 596 43 1WDP.A
# # Remove 596 596 2AQO.A
# # Remove 594 414 2F48.B
# # Remove 591 21 1EPW.A
# # Remove 590 948 1FW8.A
# # Remove 588 241 1G72.A
# # Remove 587 260 2NX9.B
# # Remove 585 59 1O98.A
# # Remove 584 102 1HBZ.A
# # Remove 583 1009 1LW3.A
# # Remove 581 40 2JAE.A
# # Remove 580 184 2CFM.A
# # Remove 579 623 1JIH.A
# # Remove 578 95 2JG2.A
# # Remove 576 456 1RA6.A
# # Remove 575 507 1FS9.A
# # Remove 574 192 2DVM.A
# # Remove 573 525 1UQT.A
# # Remove 572 526 1ADE.A
# # Remove 571 552 1W6W.A
# # Remove 570 590 1J36.A
# # Remove 568 282 1OLZ.A
# # Remove 567 5 1MUW.A
# # Remove 566 408 1ECF.B
# # Remove 565 1044 1FP4.C
# # Remove 563 313 2OHH.A
# # Remove 563 730 2P0V.A
# # Remove 561 374 1K7H.A
# # Remove 559 45 1WVF.A
# # Remove 558 49 2CXN.A
# # Remove 557 295 2NUT.A
# # Remove 556 391 1ZJC.A
# # Remove 554 30 1JEU.A
# # Remove 553 76 1WA5.C
# # Remove 552 515 1DP4.C
# # Remove 551 652 2GWD.A
# # Remove 550 938 2DU3.A
# # Remove 548 6 1SU8.A
# # Remove 547 144 1QWO.A
# # Remove 545 162 1R1H.A
# # Remove 544 541 2BVC.A
# # Remove 543 588 1JVA.B
# # Remove 541 146 1EEX.A
# # Remove 540 229 1D8W.D
# # Remove 538 338 1U6Z.B
# # Remove 537 442 1VNE._
# # Remove 536 778 2I87.B
# # Remove 534 90 1QSA.A
# # Remove 533 147 1AOP._
# # Remove 532 279 1GTT.A
# # Remove 532 455 2AC1.A
# # Remove 530 798 2BFG.A
# # Remove 529 858 2PO3.A
# # Remove 528 1028 1FVH.A
# # Remove 526 142 1I19.A
# # Remove 525 276 1M0W.B
# # Remove 524 434 1Z6T.A
# # Remove 521 24 1E4M.M
# # Remove 521 340 1Z6F.A
# # Remove 518 23 2HEU.A
# # Remove 516 31 1HBN.B
# # Remove 516 607 2C9Z.A
# # Remove 514 182 1EJD.A
# # Remove 513 943 1Z2L.A
# # Remove 511 78 1R9Z.A
# # Remove 510 426 1Q11.A
# # Remove 509 461 1QZ9.A
# # Remove 508 703 1YZY.A
# # Remove 506 661 1XUU.A
# # Remove 505 317 1Q4G.A
# # Remove 503 107 2JG0.A
# # Remove 502 237 2PW0.B
# # Remove 502 647 2CSB.A
# # Remove 501 532 2FTW.A
# # Remove 499 712 1BG1.A
# # Remove 498 892 1Q0H.A
# # Remove 496 82 2PYX.A
# # Remove 495 84 1T1U.A
# # Remove 495 351 1CGZ.A
# # Remove 493 600 2G3F.A
# # Remove 491 236 1XK7.A
# # Remove 490 597 1F61.A
# # Remove 489 621 1PP9.A
# # Remove 488 114 2FAF.A
# # Remove 486 195 1CSH._
# # Remove 485 203 1E43.A
# # Remove 483 244 1OYW.A
# # Remove 482 290 2NLI.A
# # Remove 481 625 1C4A.A
# # Remove 480 682 2DH2.A
# # Remove 478 26 1QW9.A
# # Remove 477 919 1FXX.A
# # Remove 475 362 2JER.D
# # Remove 472 149 2JFG.A
# # Remove 471 376 1FZ1.A
# # Remove 470 420 2AS0.A
# # Remove 469 561 2EH6.A
# # Remove 469 671 2E4U.B
# # Remove 465 801 1X31.B
# # Remove 464 816 1H30.A
# # Remove 462 46 2BMO.A
# # Remove 462 344 1OK7.A
# # Remove 461 980 2AAF.B
# # Remove 459 106 2HAI.A
# # Remove 458 132 1QOP.B
# # Remove 457 126 1IV8.A
# # Remove 455 312 1I1Q.A
# # Remove 453 66 1WDD.A
# # Remove 452 137 1KXQ.A
# # Remove 451 259 2GL5.A
# # Remove 450 574 1KTB.A
# # Remove 449 640 1N1Z.B
# # Remove 447 491 2B9W.A
# # Remove 446 531 1CVR.A
# # Remove 445 135 1F5N.A
# # Remove 444 775 1GC5.A
# # Remove 442 47 2J6L.B
# # Remove 441 38 1OE1.A
# # Remove 440 56 1I24.A
# # Remove 439 208 1OFL.A
# # Remove 438 460 1SQD.A
# # Remove 437 997 1RLZ.A
# # Remove 435 350 1H4P.A
# # Remove 434 807 1HL9.A
# # Remove 433 1005 1V0J.A
# # Remove 432 247 1QS1.A
# # Remove 431 885 1RI6.A
# # Remove 430 262 2E01.A
# # Remove 429 595 1RP1.A
# # Remove 427 133 2DCF.A
# # Remove 426 670 2I9U.A
# # Remove 424 246 2CZ9.A
# # Remove 423 622 1MU2.A
# # Remove 422 748 1CWV.A
# # Remove 420 219 1JY1.A
# # Remove 418 80 1OX0.A
# # Remove 417 105 2GSO.A
# # Remove 416 286 1TEZ.A
# # Remove 416 411 2GGO.A
# # Remove 414 483 2PMB.A
# # Remove 412 185 2DSN.A
# # Remove 411 474 1NSX.B
# # Remove 410 840 2FVG.A
# # Remove 409 901 1YW4.A
# # Remove 407 29 1IXH._
# # Remove 406 16 1D5T.A
# # Remove 405 328 1LML._
# # Remove 404 727 2YQH.A
# # Remove 403 753 1B57.A
# # Remove 402 218 1GAI._
# # Remove 401 421 1XFI.A
# # Remove 400 572 2DUL.A
# # Remove 400 759 1UMD.B
# # Remove 399 788 1YIR.A
# # Remove 396 140 1ODZ.A
# # Remove 395 174 2BWR.A
# # Remove 394 198 1YIZ.A
# # Remove 393 204 2P1M.B
# # Remove 392 441 1VRM.A
# # Remove 391 603 1ZAJ.A
# # Remove 390 846 2OZP.A
# # Remove 388 497 1IHG.A
# # Remove 388 651 1EK9.A
# # Remove 386 297 2J6I.A
# # Remove 384 37 2FFY.A
# # Remove 383 134 2UYT.A
# # Remove 381 116 1OGO.X
# # Remove 381 221 2Q66.A
# # Remove 380 271 1RRM.A
# # Remove 379 70 1M15.A
# # Remove 378 341 1A12.A
# # Remove 377 343 2E1V.A
# # Remove 376 591 1KA2.A
# # Remove 376 616 2F5U.A
# # Remove 373 363 1MUS.A
# # Remove 373 369 1KAX.A
# # Remove 372 443 2GLC.A
# # Remove 370 849 2POO.A
# # Remove 368 269 2DPL.A
# # Remove 368 760 1NW1.A
# # Remove 366 64 1R5Y.A
# # Remove 365 502 1N8F.A
# # Remove 364 656 1RRV.A
# # Remove 363 356 1Q25.A
# # Remove 363 881 2NRJ.A
# # Remove 361 436 1YLE.A
# # Remove 360 618 2HRZ.A
# # Remove 359 697 1IVY.A
# # Remove 358 624 1MSK._
# # Remove 356 22 1KJQ.A
# # Remove 356 589 1NR6.A
# # Remove 354 159 2AEB.A
# # Remove 353 227 1AJS.A
# # Remove 352 359 1I5P.A
# # Remove 351 440 2G8J.A
# # Remove 350 723 1OU6.A
# # Remove 348 230 7ODC.A
# # Remove 346 537 2Z1E.A
# # Remove 345 713 1ITU.A
# # Remove 345 971 2PPQ.A
# # Remove 344 819 1UJM.A
# # Remove 342 138 1ZHX.A
# # Remove 341 284 1FYF.A
# # Remove 340 375 1X7D.A
# # Remove 339 825 2Z1D.B
# # Remove 338 261 1IUQ.A
# # Remove 337 662 2QKD.A
# # Remove 335 234 2D1G.B
# # Remove 334 457 1DUV.G
# # Remove 333 988 2C5U.A
# # Remove 331 516 1MB4.A
# # Remove 330 352 1MTY.B
# # Remove 329 675 2OZG.A
# # Remove 328 210 1W5Q.A
# # Remove 326 243 2ARR.A
# # Remove 326 918 1NI9.A
# # Remove 324 445 1ZSW.A
# # Remove 323 85 2C1V.A
# # Remove 323 906 1JJU.B
# # Remove 322 296 2Z63.A
# # Remove 321 826 2ASD.A
# # Remove 320 327 1OM4.B
# # Remove 319 667 1TPZ.A
# # Remove 317 586 2Q6B.A
# # Remove 316 68 1ODM.A
# # Remove 316 150 1H2V.C
# # Remove 315 602 1FP1.D
# # Remove 314 320 2O5V.A
# # Remove 312 346 1ZY7.A
# # Remove 312 506 2BJQ.A
# # Remove 310 273 1KRH.A
# # Remove 309 72 1LS1.A
# # Remove 309 390 1Z01.A
# # Remove 308 395 1US5.A
# # Remove 307 481 4PGA.A
# # Remove 306 490 1E8U.B
# # Remove 306 855 2A0U.A
# # Remove 303 17 1JFB.A
# # Remove 302 399 1U7L.A
# # Remove 300 41 1W23.A
# # Remove 300 955 2EW2.B
# # Remove 299 334 2FOZ.A
# # Remove 298 553 2UY1.A
# # Remove 297 145 1NOF.A
# # Remove 296 863 1ZP3.B
# # Remove 294 69 1HYO.B
# # Remove 294 438 1PVG.A
# # Remove 293 382 2DSK.A
# # Remove 292 950 1MRZ.B
# # Remove 291 191 2H4A.A
# # Remove 288 103 1RDQ.E
# # Remove 288 336 1YKS.A
# # Remove 287 562 3BCT._
# # Remove 286 828 1JDW._
# # Remove 285 936 2Q8M.A
# # Remove 283 521 1B65.A
# # Remove 283 564 2BB6.A
# # Remove 281 187 1SI0.A
# # Remove 281 752 2BI0.A
# # Remove 278 51 2CNU.A
# # Remove 277 288 1BD0.A
# # Remove 277 299 1ZDY.A
# # Remove 275 323 1YW9.A
# # Remove 274 453 1VHN.A
# # Remove 273 645 4BCL._
# # Remove 273 654 1V73.A
# # Remove 272 1036 2HCJ.B
# # Remove 270 381 2B4V.A
# # Remove 270 796 2I1Q.A
# # Remove 269 605 1NVV.S
# # Remove 267 108 2H1V.A
# # Remove 266 190 2H6F.B
# # Remove 266 197 1UUQ.A
# # Remove 266 853 1ZVD.A
# # Remove 263 739 1HL2.A
# # Remove 262 743 1LRZ.A
# # Remove 261 962 2B4W.A
# # Remove 260 644 2BG5.A
# # Remove 259 787 1R3F.A
# # Remove 258 584 1CA1._
# # Remove 258 832 1L4E.A
# # Remove 256 401 2FAO.A
# # Remove 255 368 1W7B.A
# # Remove 254 660 2BO4.A
# # Remove 253 719 2CXI.A
# # Remove 251 235 1JUB.A
# # Remove 251 371 1W8K.A
# # Remove 251 428 1D4X.A
# # Remove 249 305 1Q0R.A
# # Remove 248 239 1LUC.A
# # Remove 247 649 2PGF.A
# # Remove 246 979 1OIH.A
# # Remove 244 122 2Z26.A
# # Remove 244 287 1WCW.A
# # Remove 243 256 2HQ2.A
# # Remove 241 303 1L7A.A
# # Remove 240 25 3SIL._
# # Remove 240 400 2FW0.A
# # Remove 240 1046 1ST0.A
# # Remove 238 173 2C5A.A
# # Remove 238 413 1O97.D
# # Remove 237 706 2PFZ.A
# # Remove 236 473 1FN9.A
# # Remove 235 419 1R9L.A
# # Remove 234 121 1X54.A
# # Remove 234 720 2I3S.A
# # Remove 232 309 1IJQ.A
# # Remove 231 714 1B63.A
# # Remove 230 113 2BLN.A
# # Remove 229 263 1YU0.A
# # Remove 227 504 1DC1.B
# # Remove 226 429 2HBV.A
# # Remove 226 479 1GTK.A
# # Remove 225 318 1NC5.A
# # Remove 225 784 1HV6.A
# # Remove 225 935 1NIJ.A
# # Remove 224 744 1PJC.A
# # Remove 222 510 2QM8.A
# # Remove 221 238 1EWF.A
# # Remove 219 543 2I0O.A
# # Remove 218 379 1J8U.A
# # Remove 215 314 1E19.A
# # Remove 215 911 2GTI.A
# # Remove 214 1025 1GQH.A
# # Remove 213 933 1U2Z.C
# # Remove 212 308 2BII.A
# # Remove 211 319 2C0H.A
# # Remove 211 536 1G4M.A
# # Remove 210 648 1T64.A
# # Remove 209 811 1T6K.A
# # Remove 208 61 1T2D.A
# # Remove 208 893 1N7Z.A
# # Remove 207 226 1N5U.A
# # Remove 205 42 2OB3.A
# # Remove 205 567 1M3Y.A
# # Remove 205 701 1J7X.A
# # Remove 203 345 1WRV.A
# # Remove 203 601 1BQB.A
# # Remove 201 178 2B6D.A
# # Remove 201 766 2UW1.B
# # Remove 200 202 1GVE.B
# # Remove 198 485 2CZL.A
# # Remove 198 664 1UM0.A
# # Remove 196 177 1XDN.A
# # Remove 196 731 2QCV.A
# # Remove 195 48 1N8K.A
# # Remove 194 52 1DS1.A
# # Remove 194 915 1TXD.A
# # Remove 193 12 1PJX.A
# # Remove 192 718 2PLQ.A
# # Remove 192 927 2FMS.A
# # Remove 190 579 1NXU.B
# # Remove 189 930 2GRU.A
# # Remove 188 79 1UOZ.A
# # Remove 187 1012 1TOA.A
# # Remove 187 1047 1RLM.A
# # Remove 186 32 1MJ5.A
# # Remove 186 725 2GAA.A
# # Remove 184 232 2OIT.A
# # Remove 183 272 1VCL.A
# # Remove 183 335 2AFW.A
# # Remove 183 795 1IIC.A
# # Remove 183 954 1XQ6.A
# # Remove 181 393 1RM6.B
# # Remove 181 513 2PHJ.A
# # Remove 180 937 1QLM.A
# # Remove 178 555 1QHD.A
# # Remove 178 583 2CI7.A
# # Remove 176 120 2WEA._
# # Remove 175 383 1A4I.A
# # Remove 174 469 2C7P.A
# # Remove 173 406 1QCX.A
# # Remove 173 468 1E2K.A
# # Remove 172 594 2B9E.A
# # Remove 171 741 1ONR.A
# # Remove 171 894 1WQ3.A
# # Remove 170 921 1V72.A
# # Remove 169 797 2PXJ.A
# # Remove 168 570 1GD1.O
# # Remove 167 643 1UAR.A
# # Remove 166 534 1GUP.A
# # Remove 166 792 2O62.A
# # Remove 165 728 1SP3.A
# # Remove 164 522 2J6G.A
# # Remove 162 0 1US0.A
# # Remove 162 847 2G0D.A
# # Remove 160 14 1KWF.A
# # Remove 160 458 2NWR.A
# # Remove 160 471 1B0U.A
# # Remove 159 585 1RJD.C
# # Remove 159 604 1N93.X
# # Remove 158 634 2E0A.A
# # Remove 158 978 2C4N.A
# # Remove 156 394 1CIP.A
# # Remove 155 1042 2BJG.A
# # Remove 154 820 2I5N.C
# # Remove 153 377 1JG7.A
# # Remove 152 742 1ZB1.A
# # Remove 151 764 1NAR._
# # Remove 150 53 1QTW.A
# # Remove 150 953 2FEF.A
# # Remove 149 859 2GOP.A
# # Remove 147 337 1KW3.B
# # Remove 146 302 1JL0.B
# # Remove 146 870 2F1N.A
# # Remove 145 929 1T8T.A
# # Remove 145 998 2P0A.A
# # Remove 144 565 1VFV.A
# # Remove 143 87 1Z53.A
# # Remove 143 307 2F69.A
# # Remove 142 19 1I1W.A
# # Remove 141 535 2AHX.A
# # Remove 141 729 1SML.A
# # Remove 140 581 2CB2.A
# # Remove 140 799 1F0Y.A
# # Remove 140 956 1UIR.B
# # Remove 139 976 1DXE.B
# # Remove 138 653 1SUU.A
# # Remove 137 995 1YA0.A
# # Remove 136 96 1TZB.A
# # Remove 136 673 1PGS._
# # Remove 136 934 1M6Y.A
# # Remove 134 422 1NZJ.A
# # Remove 134 726 1M8Z.A
# # Remove 132 333 1QOP.A
# # Remove 132 879 2FAW.A
# # Remove 131 131 1M4L.A
# # Remove 131 700 2GU2.A
# # Remove 129 559 1GQ8.A
# # Remove 129 890 2HOQ.A
# # Remove 128 963 1KGN.A
# # Remove 127 380 2GZS.A
# # Remove 126 112 1QJ4.A
# # Remove 126 538 1RP0.A
# # Remove 125 903 2BJV.A
# # Remove 124 985 2E5A.A
# # Remove 123 910 2OPW.A
# # Remove 122 277 2DDR.A
# # Remove 121 361 2AEX.A
# # Remove 121 386 2HHC.A
# # Remove 121 450 2F1K.A
# # Remove 120 424 1UTE.A
# # Remove 119 524 1NVM.B
# # Remove 119 1018 2OJH.A
# # Remove 118 716 2FE8.A
# # Remove 117 109 1E9G.A
# # Remove 117 556 2EB4.A
# # Remove 117 904 1O66.A
# # Remove 116 768 2P0W.B
# # Remove 115 123 1LOK.A
# # Remove 115 769 2JHN.A
# # Remove 114 435 1QV9.A
# # Remove 113 253 2OZT.A
# # Remove 113 704 2PQT.A
# # Remove 112 186 1NEY.A
# # Remove 112 563 2EHL.A
# # Remove 111 831 1IA5.A
# # Remove 110 587 1R2Z.A
# # Remove 109 889 1YCD.B
# # Remove 108 67 1GPI.A
# # Remove 108 991 2PKE.A
# # Remove 108 1049 1SR8.A
# # Remove 107 907 1TN6.A
# # Remove 107 1048 2I6D.A
# # Remove 106 736 2GSJ.A
# # Remove 105 487 2J5G.B
# # Remove 104 1039 1KO7.A
# # Remove 103 1043 1WZU.A
# # Remove 102 629 1V7Z.A
# # Remove 102 650 1JSD.A
# # Remove 101 733 1ZAR.A
# # Remove 100 93 1UWC.A
# # Remove 100 865 1ZVT.A
# # Remove 99 928 2ATM.A
# # Remove 98 347 2PHN.B
# # Remove 98 838 1YRB.B
# # Remove 97 992 1AQ0.A
# # Remove 96 115 2A3N.A
# # Remove 96 593 1FKM.A
# # Remove 95 88 1MOO.A
# # Remove 94 250 1VK1.A
# # Remove 94 482 1FIU.A
# # Remove 94 824 1VBK.A
# # Remove 93 968 2PRN._
# # Remove 93 990 1KZQ.A
# # Remove 92 128 1LC0.A
# # Remove 92 1033 2I2C.A
# # Remove 91 735 2CKI.A
# # Remove 90 612 2H8G.A
# # Remove 90 740 1ZD8.A
# # Remove 89 762 2O2X.A
# # Remove 88 311 2GS8.A
# # Remove 88 780 2HXW.A
# # Remove 88 1022 2FUE.A
# # Remove 87 493 2GCU.A
# # Remove 86 322 1GKL.A
# # Remove 86 642 1QWG.A
# # Remove 86 925 2I62.B
# # Remove 85 1051 2QIB.A
# # Remove 84 430 1NYT.A
# # Remove 84 834 1X7I.B
# # Remove 83 315 1OFZ.A
# # Remove 82 940 1C8U.A
# # Remove 81 73 1H1N.A
# # Remove 81 749 2HQY.A
# # Remove 81 1010 2O8L.A
# # Remove 80 495 2EVG.A
# # Remove 80 817 1YNS.A
# # Remove 78 27 2P74.A
# # Remove 78 384 2A8Y.A
# # Remove 78 809 2O3T.A
# # Remove 78 1038 1XRU.A
# # Remove 76 501 2NXF.A
# # Remove 76 967 2AQW.A
# # Remove 75 158 2A65.A
# # Remove 75 437 1EKQ.A
# # Remove 74 452 1H32.A
# # Remove 74 560 2GB7.B
# # Remove 73 268 1SG4.B
# # Remove 72 632 1G3M.A
# # Remove 72 657 1RV9.A
# # Remove 72 774 1YXY.A
# # Remove 72 923 1VKM.A
# # Remove 71 964 1JR7.A
# # Remove 70 222 2B2H.A
# # Remove 70 1001 2BGX.A
# # Remove 69 91 2CIW.A
# # Remove 69 767 3MAG._
# # Remove 68 270 1O9I.A
# # Remove 68 403 1YC5.A
# # Remove 68 549 2GQP.A
# # Remove 67 389 2GSM.A
# # Remove 66 118 1Z2N.X
# # Remove 66 148 2HBW.A
# # Remove 66 578 2C3N.A
# # Remove 65 11 1GCI._
# # Remove 65 492 1KQF.B
# # Remove 64 821 1B9M.A
# # Remove 63 127 1Z70.X
# # Remove 63 161 1MRO.C
# # Remove 63 283 1TVN.A
# # Remove 62 439 1MQO.A
# # Remove 62 639 1XJV.A
# # Remove 61 100 1JCL.A
# # Remove 61 924 1PQ4.A
# # Remove 60 615 2DWU.B
# # Remove 59 500 2O0A.A
# # Remove 58 255 2AGK.A
# # Remove 58 529 1WRR.A
# # Remove 58 533 1YI9.A
# # Remove 57 201 1O7Q.A
# # Remove 57 257 1O08.A
# # Remove 56 98 2A6Z.A
# # Remove 56 294 1VE4.A
# # Remove 56 520 1XD3.A
# # Remove 55 637 1GK9.A
# # Remove 55 867 1MKF.A
# # Remove 55 916 1E3D.A
# # Remove 53 705 2NW8.B
# # Remove 53 751 2I5I.A
# # Remove 53 800 2QIA.A
# # Remove 53 966 2HV6.A
# # Remove 52 814 1II5.A
# # Remove 51 223 2BJI.A
# # Remove 51 678 1EON.A
# # Remove 50 635 1I1N.A
# # Remove 50 1003 1AZO._
# # Remove 49 245 1E58.A
# # Remove 49 544 1TKE.A
# # Remove 49 709 1K8K.C
# # Remove 48 89 1ZJY.A
# # Remove 48 641 1E2W.A
# # Remove 47 164 2G8C.O
# # Remove 47 248 1KG2.A
# # Remove 47 353 1OZ2.A
# # Remove 47 794 1N45.A
# # Remove 46 412 2BKX.A
# # Remove 45 111 1FSG.A
# # Remove 45 321 1O8B.B
# # Remove 45 677 1HW1.A
# # Remove 45 872 2HBT.A
# # Remove 43 180 1W66.A
# # Remove 43 291 2DXU.A
# # Remove 42 304 1OGA.A
# # Remove 42 871 2F8Y.B
# # Remove 41 220 1JM1.A
# # Remove 41 330 1PB8.A
# # Remove 41 540 1Z3X.A
# # Remove 41 830 1JW9.B
# # Remove 41 945 1FI2.A
# # Remove 40 355 1G61.A
# # Remove 40 569 2FTN.A
# # Remove 40 630 1DFM.A
# # Remove 40 823 1W2F.A
# # Remove 39 466 1QG8.A
# # Remove 38 465 1L6R.A
# # Remove 38 694 1VHW.A
# # Remove 38 1004 2GIG.A
# # Remove 37 724 2P26.A
# # Remove 37 737 2BZG.A
# # Remove 37 851 1G60.A
# # Remove 36 402 2PXX.A
# # Remove 36 947 1VHT.A
# # Remove 35 206 1YMT.A
# # Remove 35 233 1FY2.A
# # Remove 35 557 2Z37.A
# # Remove 35 679 2F6U.A
# # Remove 35 810 2H7G.X
# # Remove 35 914 1AK0._
# # Remove 35 1027 1S5D.A
# # Remove 34 472 4EUG.A
# # Remove 34 856 1GZ9.A
# # Remove 33 154 1RQW.A
# # Remove 33 494 2F5T.X
# # Remove 32 606 1QGI.A
# # Remove 32 636 1M65.A
# # Remove 32 761 1WBH.B
# # Remove 32 1014 2JDI.G
# # Remove 31 791 1ZRU.A
# # Remove 31 852 1F5V.A
# # Remove 31 1006 1P5V.A
# # Remove 31 1026 1GXY.A
# # Remove 30 633 1SQS.A
# # Remove 30 1013 1R4X.A
# # Remove 29 423 2PQX.A
# # Remove 29 833 1DQY.A
# # Remove 28 527 1G57.B
# # Remove 28 781 1G4E.A
# # Remove 28 848 2GS5.A
# # Remove 28 898 1T0B.G
# # Remove 28 1023 1G2Q.A
# # Remove 27 842 1MVE.A
# # Remove 26 357 2FKK.A
# # Remove 26 519 3SEB._
# # Remove 26 902 1PU6.A
# # Remove 26 917 2FX5.A
# # Remove 26 1024 1V58.A
# # Remove 25 189 2HC1.A
# # Remove 25 754 2APJ.A
# # Remove 24 176 2C71.A
# # Remove 24 360 1K3Y.A
# # Remove 24 888 2O8J.B
# # Remove 23 251 1HDO.A
# # Remove 22 129 1F8D.A
# # Remove 22 459 2JC5.A
# # Remove 22 554 2D1E.A
# # Remove 22 571 1YUZ.A
# # Remove 22 696 2JHM.F
# # Remove 22 757 1TQH.A
# # Remove 22 835 1X82.A
# # Remove 22 837 1PV5.A
# # Remove 21 55 1GVK.B
# # Remove 21 827 1L3L.C
# # Remove 21 986 2DHO.A
# # Remove 21 999 2HFT._
# # Remove 20 258 2AB0.A
# # Remove 20 576 2ETX.B
# # Remove 20 922 1GQN.A
# # Remove 19 416 1WER._
# # Remove 19 523 2OXC.A
# # Remove 19 895 1IU8.A
# # Remove 19 970 1W0H.A
# # Remove 18 960 2P2V.A
# # Remove 18 1035 2FYA.A
# # Remove 17 62 1IX9.A
# # Remove 17 252 1UAI.A
# # Remove 17 298 1Z0W.A
# # Remove 17 462 2NR7.A
# # Remove 17 672 2HSJ.D
# # Remove 17 738 2OVJ.A
# # Remove 16 200 1KMV.A
# # Remove 16 777 1DI6.A
# # Remove 16 884 2HLY.A
# # Remove 16 1029 1ZQ9.A
# # Remove 15 582 1T5B.A
# # Remove 15 779 1OCY.A
# # Remove 15 868 2CL5.A
# # Remove 15 880 1SJY.A
# # Remove 14 366 1RL0.A
# # Remove 14 470 2FSQ.A
# # Remove 14 512 2EGV.A
# # Remove 13 188 1H4G.B
# # Remove 13 249 1QV1.A
# # Remove 13 278 1Q6O.B
# # Remove 13 387 2BBR.A
# # Remove 13 407 1MF7.A
# # Remove 13 658 2QJW.A
# # Remove 13 750 2ACF.D
# # Remove 13 857 1KI0.A
# # Remove 13 886 1R8S.E
# # Remove 12 829 2OQZ.A
# # Remove 12 972 2DRV.A
# # Remove 11 397 2PQ8.A
# # Remove 11 431 1LB3.A
# # Remove 11 486 1M6K.A
# # Remove 11 669 1RKU.A
# # Remove 11 722 1H99.A
# # Remove 11 804 1Y43.B
# # Remove 11 813 2PW4.A
# # Remove 11 862 2J8M.A
# # Remove 11 941 2C5Q.E
# # Remove 10 732 1YE8.A
# # Remove 10 866 1PVM.B
# # Remove 10 1031 1YKI.B
# # Remove 9 71 2H5D.A
# # Remove 9 156 2CZQ.A
# # Remove 9 467 2ODI.A
# # Remove 9 568 1UKF.A
# # Remove 9 598 2QMO.A
# # Remove 9 666 1RTT.A
# # Remove 9 896 1EP0.A
# # Remove 9 908 2BS2.C
# # Remove 9 987 1SJW.A
# # Remove 8 60 1X8P.A
# # Remove 8 175 1EB6.A
# # Remove 8 225 1PMH.X
# # Remove 8 274 1ME3.A
# # Remove 8 404 1WC2.A
# # Remove 8 499 1FX2.A
# # Remove 8 547 1ZV9.A
# # Remove 8 854 2BK7.B
# # Remove 7 358 1H4A.X
# # Remove 7 480 1QFT.A
# # Remove 7 626 2I51.B
# # Remove 7 680 1V7R.A
# # Remove 7 710 1PZ7.A
# # Remove 7 765 1UZK.A
# # Remove 7 783 1N83.A
# # Remove 7 874 2EW0.A
# # Remove 7 939 1YPY.A
# # Remove 6 125 1F9Y.A
# # Remove 6 316 1KT6.A
# # Remove 6 676 1Q7L.A
# # Remove 6 690 2FI1.A
# # Remove 6 708 2G84.A
# # Remove 6 905 2OH1.A
# # Remove 6 984 1V3W.A
# # Remove 6 996 1UGP.A
# # Remove 5 325 1I4U.A
# # Remove 5 385 1CXQ.A
# # Remove 5 410 1P6O.B
# # Remove 5 488 2I53.A
# # Remove 5 509 1KUF.A
# # Remove 5 514 2POF.A
# # Remove 5 528 1WBE.A
# # Remove 5 580 1KGD.A
# # Remove 5 803 2H8F.B
# # Remove 5 965 1T0T.V
# # Remove 5 977 1OQ1.A
# # Remove 5 983 1O9R.A
# # Remove 5 1037 1PKH.B
# # Remove 5 1050 2NW0.A
# # Remove 4 611 1T60.G
# # Remove 4 627 2A50.B
# # Remove 4 755 2BSC.A
# # Remove 4 772 2GKP.A
# # Remove 4 843 1O8X.A
# # Remove 4 926 2G7E.A
# # Remove 4 932 2B06.A
# # Remove 4 982 1JBO.A
# # Remove 4 994 1KOE.A
# # Remove 3 179 2O7A.A
# # Remove 3 211 2D5M.A
# # Remove 3 214 1TT8.A
# # Remove 3 306 1MJU.H
# # Remove 3 348 1XJU.A
# # Remove 3 475 1RG8.A
# # Remove 3 477 1UCD.A
# # Remove 3 517 1S9U.A
# # Remove 3 619 2FG1.A
# # Remove 3 638 2G7B.A
# # Remove 3 659 1M0K.A
# # Remove 3 686 1RUT.X
# # Remove 3 808 2GZ4.A
# # Remove 3 812 2GRR.B
# # Remove 3 873 2QG6.A
# # Remove 3 899 2Q5C.A
# # Remove 3 920 2HD9.A
# # Remove 3 952 1H4X.A
# # Remove 3 1019 2FCO.B
# # Remove 2 152 1XG0.D
# # Remove 2 354 1C7K.A
# # Remove 2 367 2DKO.A
# # Remove 2 433 2PND.A
# # Remove 2 489 1NQJ.B
# # Remove 2 548 1J98.A
# # Remove 2 663 1LNI.A
# # Remove 2 689 1LQP.A
# # Remove 2 717 1T3Y.A
# # Remove 2 763 1TU9.A
# # Remove 2 861 1GBS.A
# # Remove 2 913 1C52._
# # Remove 2 931 2ORW.B
# # Remove 2 959 1DMG.A
# # Remove 2 993 2FD6.U
# # Remove 1 139 1X6Z.A
# Elapsed time (m): 7.848119302590688
# Unique 1X6Z.A 0
# Unique 1NWZ.A 1
# Unique 1MC2.A 2
# Unique 1UCS.A 3
# Unique 2CE2.X 4
# Unique 1DY5.A 5
# Unique 2F01.A 6
# Unique 1EJG.A 7
# Unique 2OUR.B 8
# Unique 1R6J.A 9
# Unique 3LZT._ 10
# Unique 1Y93.A 11
# Unique 1MFM.A 12
# Unique 1TJX.A 13
# Unique 2HS1.A 14
# Unique 2GUD.A 15
# Unique 2ANV.A 16
# Unique 2BMO.B 17
# Unique 1J0P.A 18
# Unique 1UFY.A 19
# Unique 1IUA.A 20
# Unique 2PVB.A 21
# Unique 2CAL.A 22
# Unique 1Z2U.A 23
# Unique 2B97.A 24
# Unique 2NT4.A 25
# Unique 1UNQ.A 26
# Unique 2QF4.A 27
# Unique 2HAL.A 28
# Unique 1GWM.A 29
# Unique 1A6G._ 30
# Unique 1UZV.A 31
# Unique 2DSX.A 32
# Unique 1LWB.A 33
# Unique 1EUW.A 34
# Unique 1JBE.A 35
# Unique 1RW1.A 36
# Unique 1TQG.A 37
# Unique 2GJ3.A 38
# Unique 2CZ1.B 39
# Unique 2BK9.A 40
# Unique 1LU4.A 41
# Unique 1LKK.A 42
# Unique 2FLH.B 43
# Unique 2FWH.A 44
# Unique 1OH0.B 45
# Unique 2H3L.A 46
# Unique 1JF8.A 47
# Unique 1XT5.A 48
# Unique 2PQ7.A 49
# Unique 2CCW.A 50
# Unique 1MWQ.A 51
# Unique 1U2H.A 52
# Unique 2OIZ.H 53
# Unique 1KQ6.A 54
# Unique 1NWW.B 55
# Unique 2NSZ.A 56
# Unique 2B3N.A 57
# Unique 1XEO.A 58
# Unique 1IQZ.A 59
# Unique 1F86.A 60
# Unique 2BW8.A 61
# Unique 1I12.D 62
# Unique 1RYA.A 63
# Unique 1M1Q.A 64
# Unique 1MN8.D 65
# Unique 1PP0.A 66
# Unique 1VZI.A 67
# Unique 2JCQ.A 68
# Unique 2HIY.D 69
# Unique 1QXM.A 70
# Unique 2DKO.B 71
# Unique 1PSR.A 72
# Unique 1E7L.A 73
# Unique 1M9Z.A 74
# Unique 1SAU.A 75
# Unique 1GMX.A 76
# Unique 1XOD.B 77
# Unique 2B0A.A 78
# Unique 1BKR.A 79
# Unique 1XTA.A 80
# Unique 2P8G.A 81
# Unique 1GU2.A 82
# Unique 1L9L.A 83
# Unique 1ZZK.A 84
# Unique 1I8O.A 85
# Unique 1D4T.A 86
# Unique 1OK0.A 87
# Unique 1QHV.A 88
# Unique 1QDD.A 89
# Unique 1UZ3.A 90
# Unique 1K5N.B 91
# Unique 1M2D.A 92
# Unique 1PIN.A 93
# Unique 1XMK.A 94
# Unique 2H8E.A 95
# Unique 2GEC.B 96
# Unique 1V6P.A 97
# Unique 2FMA.A 98
# Unique 1ZCE.A 99
# Unique 2FJ8.A 100
# Unique 2OFK.B 101
# Unique 1DG6.A 102
# Unique 2AIB.A 103
# Unique 2A13.A 104
# Unique 1XG0.A 105
# Unique 1OOH.A 106
# Unique 1M4I.A 107
# Unique 2QCP.X 108
# Unique 1NLN.A 109
# Unique 1VBW.A 110
# Unique 1C5E.A 111
# Unique 1G6X.A 112
# Unique 2NNU.A 113
# Unique 2FHZ.A 114
# Unique 2P6W.A 115
# Unique 1O7I.A 116
# Unique 1SEN.A 117
# Unique 2UV4.A 118
# Unique 2JDA.B 119
# Unique 2QJZ.A 120
# Unique 2P0N.A 121
# Unique 2A2K.A 122
# Unique 1WVQ.A 123
# Unique 1ZMA.A 124
# Unique 1NG6.A 125
# Unique 2GYQ.A 126
# Unique 1C75.A 127
# Unique 2BS2.B 128
# Unique 1YN9.B 129
# Unique 2FYQ.A 130
# Unique 2FRG.P 131
# Unique 1I0R.B 132
# Unique 2DG5.B 133
# Unique 1X99.A 134
# Number of unique sequences: 135
